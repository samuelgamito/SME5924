# %% [markdown]
# # Lesmis

# %% [markdown]
# ## Loading Graph

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
with open('./data/raw/lesmis.txt') as f:
    for line in f:
        u,v,w = map(int, line.split())
        G.add_edge(u,v, weight=w)

# %%
pos = nx.spring_layout(G)  # layout automático

# nós e arestas
nx.draw(G, pos, with_labels=True, node_size=700, node_color="lightblue")

# pesos
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# %% [markdown]
# ## Degree Momemnt

# %% [markdown]
# $$
# \langle k^n \rangle = \frac{1}{N} \sum_{i=1}^{N} k_i^n
# $$

# %%
import numpy as np

def degree_moment(degrees, n):
    degrees = np.array(degrees)
    return np.mean(degrees ** n)

# %%
degrees = [d for _, d in G.degree()]

m1 = degree_moment(degrees, 1)  # ⟨k⟩
m2 = degree_moment(degrees, 2)  # ⟨k²⟩
m3 = degree_moment(degrees, 3)  # ⟨k³⟩
m4 = degree_moment(degrees, 4)  # ⟨k⁴⟩

print(f"⟨k³⟩ = {m3}")
print(f"⟨k⁴⟩ = {m4}")
# Out:
# ⟨k³⟩ = 1408.025974025974
# ⟨k⁴⟩ = 33592.72727272727
